# %% [markdown]
# **🎯 Objective**
#
# Understand patterns, relationships, and risks in data.

# %% [markdown]
# 1️⃣ Load Cleaned Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('../data/interim/cleaned.csv')

# %% [markdown]
# 2️⃣ Target Distribution

# %%
target = 'target_column'
sns.histplot(df[target], kde=True)
plt.show()

# %% [markdown]
# 3️⃣ Numerical Feature Distribution

# %%
df.hist(figsize=(12,8))
plt.show()

# %% [markdown]
# 4️⃣ Categorical Feature Count

# %%
for col in df.select_dtypes(include='object').columns:
    sns.countplot(y=df[col])
    plt.show()

# %% [markdown]
# 5️⃣ Correlation Analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# 6️⃣ EDA Observations (WRITE TEXT)

# %% [markdown]
# 1.   Important correlated features
# 2.   Skewed distributions
# 3.   Potential leakage

# %% [markdown]
# **📌 Purpose:** Decide preprocessing & model strategy
