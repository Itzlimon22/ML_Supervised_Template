# %% [markdown]
# 1️⃣ Saving Figures

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.hist(y_train, bins=20)
plt.title('Target Distribution')
plt.savefig('reports/figures/target_distribution.png')
plt.show()

# %% [markdown]
# 2️⃣ Creating & Saving Model Comparison CSV

# %%
import pandas as pd

results = []

# Example metrics for two models
results.append({'Model': 'Logistic Regression', 'Accuracy': 0.85, 'F1': 0.84, 'ROC_AUC': 0.88})
results.append({'Model': 'Random Forest', 'Accuracy': 0.92, 'F1': 0.91, 'ROC_AUC': 0.94})

# Convert to DataFrame
results_df = pd.DataFrame(results)
results_df.to_csv('reports/model_comparison.csv', index=False)

# %% [markdown]
# 3️⃣ Loading Model Comparison CSV

# %%
comparison_df = pd.read_csv('reports/model_comparison.csv')
print(comparison_df)
